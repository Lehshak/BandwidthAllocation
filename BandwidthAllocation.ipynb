# %%
pip install numpy matplotlib gym torch
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: gym in /opt/anaconda3/lib/python3.11/site-packages (0.26.2)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from gym) (2.2.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /opt/anaconda3/lib/python3.11/site-packages (from gym) (0.0.8)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from collections import deque

import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
from collections import deque
import torch.nn.functional as F

# %%
class RessourceEnv:
    def __init__(self, capacity=100, num_users=10):
        self.total_bandwidth = capacity  # Total available bandwidth
        self.num_users = num_users       # Number of users
        self.requests = []              # User requests

    def reset(self):
        self.requests = [random.randint(0, 20) for _ in range(self.num_users)]  # Generate random requests for each user
        return self.requests

    def step(self, allocation):
        reward = 0
        unused_bandwidth = self.total_bandwidth
        successful_allocations = 0  # Track how many requests were satisfied
        total_requested_bandwidth = sum(self.requests)  # Total bandwidth requested
        
        for i, alloc in enumerate(allocation):
            if alloc >= self.requests[i] and unused_bandwidth >= alloc:
                reward += 1  # Successful allocation
                successful_allocations += 1  # Track successful allocation
                unused_bandwidth -= alloc
        
        # Calculate unused bandwidth ratio
        unused_bandwidth_ratio = unused_bandwidth / self.total_bandwidth
        # Calculate the percentage of successful allocations
        successful_alloc_percentage = (successful_allocations / self.num_users) * 100
        
        done = True  # One-step environment
        
        # Return reward, done, unused bandwidth ratio, and successful allocation percentage
        return reward, done, unused_bandwidth_ratio, successful_alloc_percentage

# %%
class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
class DQNAgent:
    def __init__(self, state_dim, action_dim, lr, gamma, epsilon, epsilon_decay, buffer_size):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.lr = lr
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.memory = deque(maxlen=buffer_size)
        self.model = DQN(state_dim, action_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(self.action_dim)
        q_values = self.model(torch.tensor(state, dtype=torch.float32))
        return torch.argmax(q_values).item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = reward + self.gamma * torch.max(self.model(torch.tensor(next_state, dtype=torch.float32))).item()
            target_f = self.model(torch.tensor(state, dtype=torch.float32)).detach().numpy()
            target_f[action] = target
            self.optimizer.zero_grad()
            loss = nn.MSELoss()(torch.tensor(target_f), self.model(torch.tensor(state, dtype=torch.float32)))
            loss.backward()
            self.optimizer.step()
        if self.epsilon > 0.01:
            self.epsilon *= self.epsilon_decay

# %%
capacity = 200
num_users = 40
max_bandwidth = 20  # Maximum allocation per user
state_dim = num_users  # State size = number of users
action_dim = max_bandwidth + 1  # Action space size = 21 (0 to 20 bandwidth units)

# Initialize environment and agent
env = RessourceEnv(capacity=capacity, num_users=num_users)
#agent = DQNAgent(state_dim, action_dim, lr=0.001, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, buffer_size=1000)
agent = DQNAgent(state_dim, action_dim, lr=0.0005, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, buffer_size=10000)

# Run a few episodes to train the agent
num_episodes = 3000
batch_size = 30

total_test_reward = 0
total_successful_allocations = 0
total_unused_bandwidth = 0
total_successful_alloc_percentage = 0

for episode in range(num_episodes):
    state = env.reset()  # Get the initial state
    done = False
    total_reward = 0
    successful_allocations = 0
    unused_bandwidth = 0
    successful_alloc_percentage = 0

    while not done:
        # Choose an action (bandwidth allocation) based on the current state
        action = agent.act(state)
        
        # Allocate bandwidth based on the chosen action (expand action to match num_users)
        allocation = [action] * num_users  # This could be customized per user

        # Take the step in the environment
        reward, done, unused_bandwidth_ratio, successful_alloc_percentage = env.step(allocation)
        total_reward += reward
        successful_allocations += reward
        unused_bandwidth += unused_bandwidth_ratio
        successful_alloc_percentage = successful_alloc_percentage
        
        # Store the experience in memory
        next_state = env.reset()  # Reset to get a new state
        agent.remember(state, action, reward, next_state, done)
        
        # Train the agent (replay the memory)
        agent.replay(batch_size)

        state = next_state  # Update state to the next state

    # Track stats for average
    total_test_reward += total_reward
    total_successful_allocations += successful_allocations
    total_unused_bandwidth += unused_bandwidth
    total_successful_alloc_percentage += successful_alloc_percentage
    
    # Output the progress
    print(f"Episode {episode + 1}: Reward = {total_reward}, "
          f"Successful Allocations = {successful_allocations}, "
          f"Unused Bandwidth Ratio = {unused_bandwidth_ratio:.2f}, "
          f"Successful Allocation Percentage = {successful_alloc_percentage:.2f}%")

# Calculate averages
average_test_reward = total_test_reward / num_episodes
average_successful_allocations = total_successful_allocations / num_episodes
average_used_bandwidth = 1 - total_unused_bandwidth / num_episodes 
average_successful_alloc_percentage = total_successful_alloc_percentage / num_episodes

# Final averages
print(f"\nAverage Test Reward over {num_episodes} episodes: {average_test_reward}")
print(f"Average Successful Allocations: {average_successful_allocations}")
print(f"Average Used Bandwidth Ratio: {average_used_bandwidth:.2f}")
print(f"Average Successful Allocation Percentage: {average_successful_alloc_percentage:.2f}%")
# Out:
# Episode 1: Reward = 6, Successful Allocations = 6, Unused Bandwidth Ratio = 0.94, Successful Allocation Percentage = 15.00%
# Episode 2: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.70, Successful Allocation Percentage = 37.50%
# Episode 3: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.80, Successful Allocation Percentage = 25.00%
# Episode 4: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 32.50%
# Episode 5: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 40.00%
# Episode 6: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 27.50%
# Episode 7: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 8: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.02, Successful Allocation Percentage = 35.00%
# Episode 9: Reward = 8, Successful Allocations = 8, Unused Bandwidth Ratio = 0.92, Successful Allocation Percentage = 20.00%
# Episode 10: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 11: Reward = 2, Successful Allocations = 2, Unused Bandwidth Ratio = 1.00, Successful Allocation Percentage = 5.00%
# Episode 12: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.19, Successful Allocation Percentage = 45.00%
# Episode 13: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.85, Successful Allocation Percentage = 25.00%
# Episode 14: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 40.00%
# Episode 15: Reward = 2, Successful Allocations = 2, Unused Bandwidth Ratio = 0.99, Successful Allocation Percentage = 5.00%
# Episode 16: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 37.50%
# Episode 17: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.02, Successful Allocation Percentage = 35.00%
# Episode 18: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.07, Successful Allocation Percentage = 27.50%
# Episode 19: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 40.00%
# Episode 20: Reward = 0, Successful Allocations = 0, Unused Bandwidth Ratio = 1.00, Successful Allocation Percentage = 0.00%
# Episode 21: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 40.00%
# Episode 22: Reward = 12, Successful Allocations = 12, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 30.00%
# Episode 23: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 25.00%
# Episode 24: Reward = 3, Successful Allocations = 3, Unused Bandwidth Ratio = 0.97, Successful Allocation Percentage = 7.50%
# Episode 25: Reward = 12, Successful Allocations = 12, Unused Bandwidth Ratio = 0.76, Successful Allocation Percentage = 30.00%
# Episode 26: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.72, Successful Allocation Percentage = 27.50%
# Episode 27: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.58, Successful Allocation Percentage = 35.00%
# Episode 28: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.14, Successful Allocation Percentage = 47.50%
# Episode 29: Reward = 1, Successful Allocations = 1, Unused Bandwidth Ratio = 1.00, Successful Allocation Percentage = 2.50%
# Episode 30: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.75, Successful Allocation Percentage = 25.00%
# Episode 31: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 37.50%
# Episode 32: Reward = 5, Successful Allocations = 5, Unused Bandwidth Ratio = 0.93, Successful Allocation Percentage = 12.50%
# Episode 33: Reward = 3, Successful Allocations = 3, Unused Bandwidth Ratio = 0.98, Successful Allocation Percentage = 7.50%
# Episode 34: Reward = 7, Successful Allocations = 7, Unused Bandwidth Ratio = 0.82, Successful Allocation Percentage = 17.50%
# Episode 35: Reward = 7, Successful Allocations = 7, Unused Bandwidth Ratio = 0.79, Successful Allocation Percentage = 17.50%
# Episode 36: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 32.50%
# Episode 37: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.14, Successful Allocation Percentage = 47.50%
# Episode 38: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 39: Reward = 3, Successful Allocations = 3, Unused Bandwidth Ratio = 0.97, Successful Allocation Percentage = 7.50%
# Episode 40: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 37.50%
# Episode 41: Reward = 1, Successful Allocations = 1, Unused Bandwidth Ratio = 1.00, Successful Allocation Percentage = 2.50%
# Episode 42: Reward = 2, Successful Allocations = 2, Unused Bandwidth Ratio = 1.00, Successful Allocation Percentage = 5.00%
# Episode 43: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 37.50%
# Episode 44: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.37, Successful Allocation Percentage = 35.00%
# Episode 45: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 46: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 47: Reward = 3, Successful Allocations = 3, Unused Bandwidth Ratio = 0.98, Successful Allocation Percentage = 7.50%
# Episode 48: Reward = 12, Successful Allocations = 12, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 30.00%
# Episode 49: Reward = 7, Successful Allocations = 7, Unused Bandwidth Ratio = 0.90, Successful Allocation Percentage = 17.50%
# Episode 50: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 51: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.83, Successful Allocation Percentage = 27.50%
# Episode 52: Reward = 12, Successful Allocations = 12, Unused Bandwidth Ratio = 0.76, Successful Allocation Percentage = 30.00%
# Episode 53: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 25.00%
# Episode 54: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.36, Successful Allocation Percentage = 40.00%
# Episode 55: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 40.00%
# Episode 56: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.65, Successful Allocation Percentage = 35.00%
# Episode 57: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 58: Reward = 8, Successful Allocations = 8, Unused Bandwidth Ratio = 0.84, Successful Allocation Percentage = 20.00%
# Episode 59: Reward = 8, Successful Allocations = 8, Unused Bandwidth Ratio = 0.80, Successful Allocation Percentage = 20.00%
# Episode 60: Reward = 9, Successful Allocations = 9, Unused Bandwidth Ratio = 0.73, Successful Allocation Percentage = 22.50%
# Episode 61: Reward = 3, Successful Allocations = 3, Unused Bandwidth Ratio = 0.98, Successful Allocation Percentage = 7.50%
# Episode 62: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 45.00%
# Episode 63: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 37.50%
# Episode 64: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 65: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 66: Reward = 7, Successful Allocations = 7, Unused Bandwidth Ratio = 0.86, Successful Allocation Percentage = 17.50%
# Episode 67: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.20, Successful Allocation Percentage = 40.00%
# Episode 68: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 69: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 27.50%
# Episode 70: Reward = 12, Successful Allocations = 12, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 30.00%
# Episode 71: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 32.50%
# Episode 72: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 73: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 74: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.02, Successful Allocation Percentage = 35.00%
# Episode 75: Reward = 21, Successful Allocations = 21, Unused Bandwidth Ratio = 0.06, Successful Allocation Percentage = 52.50%
# Episode 76: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 27.50%
# Episode 77: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 78: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 79: Reward = 3, Successful Allocations = 3, Unused Bandwidth Ratio = 0.98, Successful Allocation Percentage = 7.50%
# Episode 80: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 81: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.40, Successful Allocation Percentage = 37.50%
# Episode 82: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 83: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 27.50%
# Episode 84: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.07, Successful Allocation Percentage = 42.50%
# Episode 85: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 86: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 87: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 88: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 45.00%
# Episode 89: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 32.50%
# Episode 90: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 91: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.32, Successful Allocation Percentage = 42.50%
# Episode 92: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 93: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 94: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 95: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.44, Successful Allocation Percentage = 40.00%
# Episode 96: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 97: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.70, Successful Allocation Percentage = 37.50%
# Episode 98: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 27.50%
# Episode 99: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.61, Successful Allocation Percentage = 32.50%
# Episode 100: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 25.00%
# Episode 101: Reward = 21, Successful Allocations = 21, Unused Bandwidth Ratio = 0.06, Successful Allocation Percentage = 52.50%
# Episode 102: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 32.50%
# Episode 103: Reward = 2, Successful Allocations = 2, Unused Bandwidth Ratio = 0.99, Successful Allocation Percentage = 5.00%
# Episode 104: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 105: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.72, Successful Allocation Percentage = 35.00%
# Episode 106: Reward = 8, Successful Allocations = 8, Unused Bandwidth Ratio = 0.88, Successful Allocation Percentage = 20.00%
# Episode 107: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.19, Successful Allocation Percentage = 45.00%
# Episode 108: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 109: Reward = 21, Successful Allocations = 21, Unused Bandwidth Ratio = 0.06, Successful Allocation Percentage = 52.50%
# Episode 110: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 111: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.30, Successful Allocation Percentage = 50.00%
# Episode 112: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 25.00%
# Episode 113: Reward = 10, Successful Allocations = 10, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 25.00%
# Episode 114: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 115: Reward = 12, Successful Allocations = 12, Unused Bandwidth Ratio = 0.82, Successful Allocation Percentage = 30.00%
# Episode 116: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.03, Successful Allocation Percentage = 37.50%
# Episode 117: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.72, Successful Allocation Percentage = 27.50%
# Episode 118: Reward = 3, Successful Allocations = 3, Unused Bandwidth Ratio = 0.98, Successful Allocation Percentage = 7.50%
# Episode 119: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0
Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 375: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.25, Successful Allocation Percentage = 37.50%
# Episode 376: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# ...
# Episode 2879: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.19, Successful Allocation Percentage = 45.00%
# Episode 2880: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2881: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2882: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2883: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2884: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2885: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 2886: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2887: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.20, Successful Allocation Percentage = 40.00%
# Episode 2888: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2889: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 2890: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2891: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2892: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 50.00%
# Episode 2893: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2894: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.20, Successful Allocation Percentage = 40.00%
# Episode 2895: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 50.00%
# Episode 2896: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.23, Successful Allocation Percentage = 42.50%
# Episode 2897: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2898: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2899: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2900: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2901: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.24, Successful Allocation Percentage = 47.50%
# Episode 2902: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2903: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2904: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2905: Reward = 21, Successful Allocations = 21, Unused Bandwidth Ratio = 0.06, Successful Allocation Percentage = 52.50%
# Episode 2906: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2907: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2908: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2909: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2910: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2911: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2912: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.33, Successful Allocation Percentage = 37.50%
# Episode 2913: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2914: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2915: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2916: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2917: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.35, Successful Allocation Percentage = 32.50%
# Episode 2918: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2919: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2920: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2921: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2922: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2923: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 2924: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2925: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 2926: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2927: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2928: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2929: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 50.00%
# Episode 2930: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2931: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2932: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2933: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.14, Successful Allocation Percentage = 47.50%
# Episode 2934: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2935: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2936: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 45.00%
# Episode 2937: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 50.00%
# Episode 2938: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2939: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2940: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2941: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 2942: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2943: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 2944: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 50.00%
# Episode 2945: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2946: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2947: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2948: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2949: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2950: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2951: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2952: Reward = 11, Successful Allocations = 11, Unused Bandwidth Ratio = 0.72, Successful Allocation Percentage = 27.50%
# Episode 2953: Reward = 16, Successful Allocations = 16, Unused Bandwidth Ratio = 0.20, Successful Allocation Percentage = 40.00%
# Episode 2954: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 2955: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 45.00%
# Episode 2956: Reward = 15, Successful Allocations = 15, Unused Bandwidth Ratio = 0.25, Successful Allocation Percentage = 37.50%
# Episode 2957: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2958: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 2959: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.23, Successful Allocation Percentage = 42.50%
# Episode 2960: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2961: Reward = 12, Successful Allocations = 12, Unused Bandwidth Ratio = 0.04, Successful Allocation Percentage = 30.00%
# Episode 2962: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2963: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2964: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2965: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2966: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 2967: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2968: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2969: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 2970: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2971: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2972: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2973: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2974: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2975: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2976: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2977: Reward = 17, Successful Allocations = 17, Unused Bandwidth Ratio = 0.15, Successful Allocation Percentage = 42.50%
# Episode 2978: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.14, Successful Allocation Percentage = 47.50%
# Episode 2979: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2980: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2981: Reward = 22, Successful Allocations = 22, Unused Bandwidth Ratio = 0.01, Successful Allocation Percentage = 55.00%
# Episode 2982: Reward = 14, Successful Allocations = 14, Unused Bandwidth Ratio = 0.37, Successful Allocation Percentage = 35.00%
# Episode 2983: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 50.00%
# Episode 2984: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2985: Reward = 19, Successful Allocations = 19, Unused Bandwidth Ratio = 0.05, Successful Allocation Percentage = 47.50%
# Episode 2986: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.10, Successful Allocation Percentage = 45.00%
# Episode 2987: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2988: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2989: Reward = 18, Successful Allocations = 18, Unused Bandwidth Ratio = 0.19, Successful Allocation Percentage = 45.00%
# Episode 2990: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2991: Reward = 13, Successful Allocations = 13, Unused Bandwidth Ratio = 0.35, Successful Allocation Percentage = 32.50%
# Episode 2992: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2993: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2994: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2995: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2996: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2997: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2998: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 2999: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
# Episode 3000: Reward = 20, Successful Allocations = 20, Unused Bandwidth Ratio = 0.00, Successful Allocation Percentage = 50.00%
#
# Average Test Reward over 3000 episodes: 18.538333333333334
# Average Successful Allocations: 18.538333333333334
# Average Used Bandwidth Ratio: 0.92
# Average Successful Allocation Percentage: 46.35%
